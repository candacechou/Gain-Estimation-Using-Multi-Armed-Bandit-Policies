# %% [markdown]
# # KLUCB with Single Frequency Strategy
#
# $\sigma$ = 0.1

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from bandit import Bandits
from KLUCB import KLUCB_Single_Freq
from Result_Visualization import System_Gain_Estimation,Plot_mean_square_error
from Regret import Model_Regret
from Model_Analysis import  Plot_Chosen_Time,System_Gain_Estimation_UCB

# %% [markdown]
# ## Experiment 1

# %%
B     = [0.1023, -0.1050, -0.0734, -0.2553, -0.0331, 0.2257, -0.0607, -0.2380, -0.0664, -0.1164, 0.1056]
A     = [1]
K     = 50
N     = 100000
sigma = 0.1
name  = 'KLUCB'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %% [markdown]
# ### Create a bandit Object

# %%
bandit = Bandits(A,B,K)

bandit.print_hinf_norm()
bandit.plot_real_system()
c = 3
Model_UCBSF = KLUCB_Single_Freq(bandit,sigma,N,name,c,"1")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 0.7415136824155119 Which is in arm :  19

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF)
Plot_Chosen_Time(Model_UCBSF)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 1
savefig = True
frame = 3000
Regret_UCBSF = Model_Regret(Model_UCBSF,Kn)
Regret_UCBSF.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# !here
# The 1th model with the overall Regret: 73.40809019060302

# %%
Kn = 50
savefig = True
frame = 3000
Regret_UCBSF = Model_Regret(Model_UCBSF,Kn)
Regret_UCBSF.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 76.3143175720841
# here
# The 2th model with the overall Regret: 67.88951480483114
# here
# The 3th model with the overall Regret: 90.26296363980464
# here
# The 4th model with the overall Regret: 78.67666662241044
# here
# The 5th model with the overall Regret: 61.789138698178185
# here
# The 6th model with the overall Regret: 73.023065682788
# here
# The 7th model with the overall Regret: 92.02347886470484
# here
# The 8th model with the overall Regret: 72.04417474979988
# here
# The 9th model with the overall Regret: 83.3992683426721
# here
# The 10th model with the overall Regret: 72.61867762262732
# here
# The 11th model with the overall Regret: 79.17471206433333
# here
# The 12th model with the overall Regret: 75.10404706985955
# here
# The 13th model with the overall Regret: 74.50814366659348
# here
# The 14th model with the overall Regret: 72.96331291506742
# here
# The 15th model with the overall Regret: 73.7550701381056
# here
# The 16th model with the overall Regret: 65.51726706553592
# here
# The 17th model with the overall Regret: 70.25015023186849
# here
# The 18th model with the overall Regret: 77.25307074457585
# here
# The 19th model with the overall Regret: 69.60883572202597
# here
# The 20th model with the overall Regret: 74.33158923375001
# here
# The 21th model with the overall Regret: 79.24056014852171
# here
# The 22th model with the overall Regret: 80.8667439313526
# here
# The 23th model with the overall Regret: 81.60043778303454
# here
# The 24th model with the overall Regret: 73.53133306174647
# here
# The 25th model with the overall Regret: 67.10394289033934
# here
# The 26th model with the overall Regret: 80.51873111272313
# here
# The 27th model with the overall Regret: 85.0222355627898
# here
# The 28th model with the overall Regret: 83.96707933544421
# here
# The 29th model with the overall Regret: 74.34428520858361
# here
# The 30th model with the overall Regret: 81.79002340905214
# here
# The 31th model with the overall Regret: 75.08683886838152
# here
# The 32th model with the overall Regret: 74.79551539229679
# here
# The 33th model with the overall Regret: 70.46801110161357
# here
# The 34th model with the overall Regret: 70.61850702190779
# here
# The 35th model with the overall Regret: 74.35712575396315
# here
# The 36th model with the overall Regret: 73.8796426222435
# here
# The 37th model with the overall Regret: 73.9818916103087
# here
# The 38th model with the overall Regret: 73.55296169961976
# here
# The 39th model with the overall Regret: 87.55050027902048
# here
# The 40th model with the overall Regret: 72.85531718816793
# here
# The 41th model with the overall Regret: 86.80451291472644
# here
# The 42th model with the overall Regret: 74.78839789721326
# here
# The 43th model with the overall Regret: 90.45407783606383
# here
# The 44th model with the overall Regret: 90.31519240035288
# here
# The 45th model with the overall Regret: 79.3677050246349
# here
# The 46th model with the overall Regret: 92.36813842110895
# here
# The 47th model with the overall Regret: 75.21483649216162
# here
# The 48th model with the overall Regret: 88.57896645951966
# here
# The 49th model with the overall Regret: 78.74369349139586
# !here
# The 50th model with the overall Regret: 74.71984769801712

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF)
Plot_Chosen_Time(Model_UCBSF)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
plt.figure()
for i in range(Kn): 
    plt.plot(range(len(Regret_UCBSF.regret[:,i])),Regret_UCBSF.regret[:,i])
plt.xlabel("Time")
plt.ylabel("Regret")
plt.title("The regret of each model.")
plt.show()

# %% [markdown]
# ### Plot the Expected regret

# %%
Regret_UCBSF.Plot_Regret()

# %% [markdown]
# ### Plot the Mean Square Error

# %%
Regret_UCBSF.Plot_MSE()

# %% [markdown]
# ### Plot Regret with Regret lower bound on in semi-log

# %%
Regret_UCBSF.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
Regret_UCBSF.Plot_MSE()

# %% [markdown]
# ### Save the Experiment 1 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBSF_50arms_1e5rounds_EX1.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBSF, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Experiment 2

# %%
B     = [0.433, -0.3050, 0.0734, 0.1257, 0.0607, -0.2380, -0.2553, -0.0331, 0.0364, 0.1664, -0.425]
A     = [1]
K      = 66
N     = 100000
sigma = 0.1
c = 3
name  = 'KLUCB'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %%
bandit = Bandits(A,B,K)
bandit.print_hinf_norm()
bandit.plot_real_system()
Model_UCBSF1 = KLUCB_Single_Freq(bandit,sigma,N,name,c,"2")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 1.823838133951191 Which is in arm :  59

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF1)
Plot_Chosen_Time(Model_UCBSF1)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 3000
Regret_UCBSF1 = Model_Regret(Model_UCBSF1,Kn)
Regret_UCBSF1.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 115.77697675389915
# here
# The 2th model with the overall Regret: 103.49068054347372
# here
# The 3th model with the overall Regret: 118.97732137303244
# here
# The 4th model with the overall Regret: 109.73501858718404
# here
# The 5th model with the overall Regret: 105.98007124898851
# here
# The 6th model with the overall Regret: 120.40410144002529
# here
# The 7th model with the overall Regret: 131.2446098660234
# here
# The 8th model with the overall Regret: 144.82481132683935
# here
# The 9th model with the overall Regret: 120.89741455497347
# here
# The 10th model with the overall Regret: 135.58116244595007
# here
# The 11th model with the overall Regret: 107.54931271631328
# here
# The 12th model with the overall Regret: 89.4434785632697
# here
# The 13th model with the overall Regret: 102.5855839481011
# here
# The 14th model with the overall Regret: 147.8958961938774
# here
# The 15th model with the overall Regret: 130.34288675976498
# here
# The 16th model with the overall Regret: 118.15126743752478
# here
# The 17th model with the overall Regret: 121.10987466239011
# here
# The 18th model with the overall Regret: 98.5048535527527
# here
# The 19th model with the overall Regret: 107.5204952280445
# here
# The 20th model with the overall Regret: 113.98661902073457
# here
# The 21th model with the overall Regret: 112.61100726991108
# here
# The 22th model with the overall Regret: 113.314244880387
# here
# The 23th model with the overall Regret: 109.50809301795262
# here
# The 24th model with the overall Regret: 580.520727689213
# here
# The 25th model with the overall Regret: 114.43865298193515
# here
# The 26th model with the overall Regret: 132.3876852602865
# here
# The 27th model with the overall Regret: 115.86313331001486
# here
# The 28th model with the overall Regret: 137.57065492381932
# here
# The 29th model with the overall Regret: 147.66103860783332
# here
# The 30th model with the overall Regret: 120.98807733349165
# here
# The 31th model with the overall Regret: 112.71476314461849
# here
# The 32th model with the overall Regret: 113.60232119608429
# here
# The 33th model with the overall Regret: 141.11598624451514
# here
# The 34th model with the overall Regret: 121.0873632006732
# here
# The 35th model with the overall Regret: 128.78234131855524
# here
# The 36th model with the overall Regret: 130.50064455266917
# here
# The 37th model with the overall Regret: 131.8830163487835
# here
# The 38th model with the overall Regret: 118.32261691888608
# here
# The 39th model with the overall Regret: 108.38063326902672
# here
# The 40th model with the overall Regret: 121.93528114638798
# here
# The 41th model with the overall Regret: 126.07087579203645
# here
# The 42th model with the overall Regret: 113.9806541241582
# here
# The 43th model with the overall Regret: 119.90148187195008
# here
# The 44th model with the overall Regret: 115.24193039013679
# here
# The 45th model with the overall Regret: 129.52524565439103
# here
# The 46th model with the overall Regret: 116.75291309315062
# here
# The 47th model with the overall Regret: 123.18077448327399
# here
# The 48th model with the overall Regret: 159.17685840960152
# here
# The 49th model with the overall Regret: 113.92285164475415
# !here
# The 50th model with the overall Regret: 129.66470814204527

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF1)
Plot_Chosen_Time(Model_UCBSF1)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
Regret_UCBSF1.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
Regret_UCBSF1.Plot_MSE()

# %% [markdown]
# ### Save the Experiment 2 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBSF_66arms_1e5rounds_EX2.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBSF1, handle, protocol=pickle.HIGHEST_PROTOCOL)
