# %% [markdown]
# # KLUCBplus with Single Frequency Strategy
#
# $\sigma$ = 0.1

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from bandit import Bandits
from KLUCB import KLUCB_Single_Freq
from Result_Visualization import System_Gain_Estimation,Plot_mean_square_error
from Regret import Model_Regret
from Model_Analysis import  Plot_Chosen_Time,System_Gain_Estimation_UCB

# %% [markdown]
# ## Experiment 1

# %%
B     = [0.1023, -0.1050, -0.0734, -0.2553, -0.0331, 0.2257, -0.0607, -0.2380, -0.0664, -0.1164, 0.1056]
A     = [1]
K     = 50
N     = 100000
sigma = 0.1
name  = 'KLUCB-Plus'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %% [markdown]
# ### Create a bandit Object

# %%
bandit = Bandits(A,B,K)

bandit.print_hinf_norm()
bandit.plot_real_system()
c = 3
Model_UCBSF = KLUCB_Single_Freq(bandit,sigma,N,name,c,"1")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 0.7415136824155119 Which is in arm :  19

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF)
Plot_Chosen_Time(Model_UCBSF)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 3000
Regret_UCBSF = Model_Regret(Model_UCBSF,Kn)
Regret_UCBSF.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 79.92740803553583
# here
# The 2th model with the overall Regret: 76.4124863719098
# here
# The 3th model with the overall Regret: 63.681927473918584
# here
# The 4th model with the overall Regret: 73.00339600338101
# here
# The 5th model with the overall Regret: 73.73701031820039
# here
# The 6th model with the overall Regret: 77.1482117332031
# here
# The 7th model with the overall Regret: 84.71751557761571
# here
# The 8th model with the overall Regret: 79.25823931505523
# here
# The 9th model with the overall Regret: 76.07848507432105
# here
# The 10th model with the overall Regret: 72.70665747291766
# here
# The 11th model with the overall Regret: 79.02050850698356
# here
# The 12th model with the overall Regret: 84.94087911397403
# here
# The 13th model with the overall Regret: 78.62322707361423
# here
# The 14th model with the overall Regret: 71.47645830799354
# here
# The 15th model with the overall Regret: 83.94092005936568
# here
# The 16th model with the overall Regret: 72.77249575415699
# here
# The 17th model with the overall Regret: 82.60934414068197
# here
# The 18th model with the overall Regret: 88.11013358043
# here
# The 19th model with the overall Regret: 82.15038319475471
# here
# The 20th model with the overall Regret: 72.488016744357
# here
# The 21th model with the overall Regret: 81.327822581704
# here
# The 22th model with the overall Regret: 85.3143276540394
# here
# The 23th model with the overall Regret: 76.19961661707107
# here
# The 24th model with the overall Regret: 73.42904415357891
# here
# The 25th model with the overall Regret: 69.84523095861951
# here
# The 26th model with the overall Regret: 83.48649776314156
# here
# The 27th model with the overall Regret: 79.23861185060986
# here
# The 28th model with the overall Regret: 82.44609376878795
# here
# The 29th model with the overall Regret: 78.14238500588074
# here
# The 30th model with the overall Regret: 74.9602596292572
# here
# The 31th model with the overall Regret: 71.65454197345815
# here
# The 32th model with the overall Regret: 68.39488980280642
# here
# The 33th model with the overall Regret: 84.58241126956527
# here
# The 34th model with the overall Regret: 70.45043521635924
# here
# The 35th model with the overall Regret: 71.90732222466892
# here
# The 36th model with the overall Regret: 71.51859467524665
# here
# The 37th model with the overall Regret: 72.01652815165365
# here
# The 38th model with the overall Regret: 74.88193976561234
# here
# The 39th model with the overall Regret: 69.09197840799993
# here
# The 40th model with the overall Regret: 78.45144464972935
# here
# The 41th model with the overall Regret: 77.40286090397386
# here
# The 42th model with the overall Regret: 93.39205666825674
# here
# The 43th model with the overall Regret: 76.22969355582063
# here
# The 44th model with the overall Regret: 67.62312109961023
# here
# The 45th model with the overall Regret: 71.37334994158628
# here
# The 46th model with the overall Regret: 77.95555799868605
# here
# The 47th model with the overall Regret: 85.60294210828629
# here
# The 48th model with the overall Regret: 82.89383729048221
# here
# The 49th model with the overall Regret: 90.3341484043943
# !here
# The 50th model with the overall Regret: 84.57464928070645

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF)
Plot_Chosen_Time(Model_UCBSF)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
plt.figure()
for i in range(Kn): 
    plt.plot(range(len(Regret_UCBSF.regret[:,i])),Regret_UCBSF.regret[:,i])
plt.xlabel("Time")
plt.ylabel("Regret")
plt.title("The regret of each model.")
plt.show()

# %% [markdown]
# ### Plot the Expected regret

# %%
Regret_UCBSF.Plot_Regret()

# %% [markdown]
# ### Plot the Mean Square Error

# %%
Regret_UCBSF.Plot_MSE()

# %% [markdown]
# ### Plot Regret with Regret lower bound on in semi-log

# %%
Regret_UCBSF.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
Regret_UCBSF.Plot_MSE()

# %% [markdown]
# ### Save the Experiment 1 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBplusSF_50arms_1e5rounds_EX1.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBSF, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Experiment 2

# %%
B     = [0.433, -0.3050, 0.0734, 0.1257, 0.0607, -0.2380, -0.2553, -0.0331, 0.0364, 0.1664, -0.425]
A     = [1]
K      = 66
N     = 100000
sigma = 0.1
c = 3
name  = 'KLUCB-Plus'

# %%
bandit = Bandits(A,B,K)
bandit.print_hinf_norm()
bandit.plot_real_system()
Model_UCBSF1 = KLUCB_Single_Freq(bandit,sigma,N,name,c,"2")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 1.823838133951191 Which is in arm :  59

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF1)
Plot_Chosen_Time(Model_UCBSF1)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 3000
Regret_UCBSF1 = Model_Regret(Model_UCBSF1,Kn)
Regret_UCBSF1.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 103.92068010700133
# here
# The 2th model with the overall Regret: 118.96146331321354
# here
# The 3th model with the overall Regret: 119.65498967067172
# here
# The 4th model with the overall Regret: 110.7279398500981
# here
# The 5th model with the overall Regret: 134.28816372641666
# here
# The 6th model with the overall Regret: 129.14993379750686
# here
# The 7th model with the overall Regret: 114.43583623838533
# here
# The 8th model with the overall Regret: 135.30304641005313
# here
# The 9th model with the overall Regret: 126.50627239645034
# here
# The 10th model with the overall Regret: 111.47338625029491
# here
# The 11th model with the overall Regret: 137.45686972886432
# here
# The 12th model with the overall Regret: 111.66471456208006
# here
# The 13th model with the overall Regret: 117.47208266470629
# here
# The 14th model with the overall Regret: 134.8761996332689
# here
# The 15th model with the overall Regret: 145.0310353161727
# here
# The 16th model with the overall Regret: 120.99104449924411
# here
# The 17th model with the overall Regret: 128.80088051787678
# here
# The 18th model with the overall Regret: 121.41682796655186
# here
# The 19th model with the overall Regret: 129.68157137579783
# here
# The 20th model with the overall Regret: 155.5703051774683
# here
# The 21th model with the overall Regret: 118.29860712355418
# here
# The 22th model with the overall Regret: 129.18925881525038
# here
# The 23th model with the overall Regret: 135.6494330219669
# here
# The 24th model with the overall Regret: 127.42932761246398
# here
# The 25th model with the overall Regret: 120.05638587268207
# here
# The 26th model with the overall Regret: 126.79512465890981
# here
# The 27th model with the overall Regret: 110.08723172852075
# here
# The 28th model with the overall Regret: 121.10794532266831
# here
# The 29th model with the overall Regret: 115.0746196886017
# here
# The 30th model with the overall Regret: 118.94394533589319
# here
# The 31th model with the overall Regret: 115.09087217542697
# here
# The 32th model with the overall Regret: 119.97197933917299
# here
# The 33th model with the overall Regret: 103.26470175479957
# here
# The 34th model with the overall Regret: 120.8865687202994
# here
# The 35th model with the overall Regret: 128.09379239821186
# here
# The 36th model with the overall Regret: 109.912535279006
# here
# The 37th model with the overall Regret: 112.36487751030388
# here
# The 38th model with the overall Regret: 96.09950912276638
# here
# The 39th model with the overall Regret: 123.3956286162715
# here
# The 40th model with the overall Regret: 115.38437512933251
# here
# The 41th model with the overall Regret: 123.65923137253284
# here
# The 42th model with the overall Regret: 130.87887648263606
# here
# The 43th model with the overall Regret: 127.21579969784842
# here
# The 44th model with the overall Regret: 112.40042154009531
# here
# The 45th model with the overall Regret: 108.95297034529844
# here
# The 46th model with the overall Regret: 126.25232172323574
# here
# The 47th model with the overall Regret: 118.99716076067197
# here
# The 48th model with the overall Regret: 109.76970023289392
# here
# The 49th model with the overall Regret: 104.87008676311383
# !here
# The 50th model with the overall Regret: 120.60944548779372

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF1)
Plot_Chosen_Time(Model_UCBSF1)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
Regret_UCBSF1.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
Regret_UCBSF1.Plot_MSE()

# %% [markdown]
# ### Save the Experiment 2 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBplusSF_66arms_1e5rounds_EX2.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBSF1, handle, protocol=pickle.HIGHEST_PROTOCOL)
