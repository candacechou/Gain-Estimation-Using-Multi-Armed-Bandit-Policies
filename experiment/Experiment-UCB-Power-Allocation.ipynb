# %% [markdown]
# # UCB with Power Allocation Strategy
#
# $\sigma$ = 0.1

# %%
# !pip install imageio-ffmpeg
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from bandit import Bandits
from UCB import UCB_Power_Allocation
from Result_Visualization import System_Gain_Estimation,Plot_mean_square_error
from Regret import Model_Regret
from Model_Analysis import Plot_Chosen_Time,System_Gain_Estimation_UCB
# Out:
# Requirement already satisfied: imageio-ffmpeg in /Users/candacechou/opt/anaconda3/lib/python3.8/site-packages (0.4.8)

# %% [markdown]
# ## Experiment 1

# %%
B     = [0.1023, -0.1050, -0.0734, -0.2553, -0.0331, 0.2257, -0.0607, -0.2380, -0.0664, -0.1164, 0.1056]
A     = [1]
K     = 50
N     = 100000
sigma = 0.1
beta  = 1
name  = 'UCB_Power_Allocation'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %% [markdown]
# ### Create a bandit Object

# %%
bandit = Bandits(A,B,K)

bandit.print_hinf_norm()
bandit.plot_real_system()

Model_UCBPA = UCB_Power_Allocation(bandit,sigma,N,prior,name,beta,"1")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 0.7415136824155119 Which is in arm :  19

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBPA)
Plot_Chosen_Time(Model_UCBPA)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 5000
Regret_UCBPA = Model_Regret(Model_UCBPA,Kn)
Regret_UCBPA.Compute_Regret(showed=False,savefig = savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 50.91092081666722
# here
# The 2th model with the overall Regret: 50.95360124721666
# here
# The 3th model with the overall Regret: 53.256239595495664
# here
# The 4th model with the overall Regret: 49.11725104269012
# here
# The 5th model with the overall Regret: 56.0863863803231
# here
# The 6th model with the overall Regret: 58.073461072224816
# here
# The 7th model with the overall Regret: 61.92904594564577
# here
# The 8th model with the overall Regret: 43.6723445071958
# here
# The 9th model with the overall Regret: 67.75282578766588
# here
# The 10th model with the overall Regret: 60.77646039215631
# here
# The 11th model with the overall Regret: 43.96383547610482
# here
# The 12th model with the overall Regret: 43.72759466531311
# here
# The 13th model with the overall Regret: 54.675975267469745
# here
# The 14th model with the overall Regret: 50.392829851396684
# here
# The 15th model with the overall Regret: 55.63573785618058
# here
# The 16th model with the overall Regret: 60.041177280735745
# here
# The 17th model with the overall Regret: 57.663873417868714
# here
# The 18th model with the overall Regret: 47.65120025301823
# here
# The 19th model with the overall Regret: 52.61666219783811
# here
# The 20th model with the overall Regret: 49.14747593907108
# here
# The 21th model with the overall Regret: 49.19841100764191
# here
# The 22th model with the overall Regret: 45.89292381896569
# here
# The 23th model with the overall Regret: 53.96048214619473
# here
# The 24th model with the overall Regret: 46.21574905786973
# here
# The 25th model with the overall Regret: 63.81543754244045
# here
# The 26th model with the overall Regret: 60.07796345298764
# here
# The 27th model with the overall Regret: 58.107237140078155
# here
# The 28th model with the overall Regret: 54.7113341840059
# here
# The 29th model with the overall Regret: 48.73495337598803
# here
# The 30th model with the overall Regret: 49.443797699788014
# here
# The 31th model with the overall Regret: 69.31127649099793
# here
# The 32th model with the overall Regret: 60.40988991089955
# here
# The 33th model with the overall Regret: 52.57831851329329
# here
# The 34th model with the overall Regret: 43.87798689535552
# here
# The 35th model with the overall Regret: 49.394518162979786
# here
# The 36th model with the overall Regret: 51.60138286710095
# here
# The 37th model with the overall Regret: 59.36763048796824
# here
# The 38th model with the overall Regret: 75.6056676716278
# here
# The 39th model with the overall Regret: 43.55295059567404
# here
# The 40th model with the overall Regret: 46.00960368047993
# here
# The 41th model with the overall Regret: 46.120472228101846
# here
# The 42th model with the overall Regret: 50.804016648566105
# here
# The 43th model with the overall Regret: 55.30547373592806
# here
# The 44th model with the overall Regret: 59.54936340683258
# here
# The 45th model with the overall Regret: 46.66506524949105
# here
# The 46th model with the overall Regret: 60.82005906211424
# here
# The 47th model with the overall Regret: 51.625713790879765
# here
# The 48th model with the overall Regret: 55.91045948750029
# here
# The 49th model with the overall Regret: 56.021281229068876
# here
# The 50th model with the overall Regret: 47.65123458257912

# %%
Kn = 1
savefig = True
frame = 5000
Regret_UCBPA = Model_Regret(Model_UCBPA,Kn)
Regret_UCBPA.Compute_Regret(showed=False,savefig = savefig,frame=frame)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
plt.figure()
for i in range(Kn): 
    plt.plot(range(len(Regret_UCBPA.regret[:,i])),Regret_UCBPA.regret[:,i])
plt.xlabel("Time")
plt.ylabel("Regret")
plt.title("The regret of each model.")
plt.show()

# %% [markdown]
# ### Plot the Expected regret

# %%
Regret_UCBPA.Plot_Regret()

# %% [markdown]
# ### Plot the Mean Square Error

# %%
Regret_UCBPA.Plot_MSE()

# %% [markdown]
# ### Plot Regret with Regret lower bound on in semi-log

# %%
Regret_UCBPA.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
plt.figure()
plt.semilogy(Regret_UCBPA.MSE,label = 'MSE1')
plt.plot(Regret_UCBPA.MSE1,label = 'MSE2')
plt.title("Mean Square Error of the experiment.")
plt.xlabel("Time t")
plt.ylabel("MSE")

plt.legend()
plt.show()

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBPA)
Plot_Chosen_Time(Model_UCBPA)

# %% [markdown]
# ### Save the Experiment 1 Result for Further Analysis

# %%
import pickle
with open('./Result/UCBPA_50arms_1e5rounds_EX1.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBPA, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Experiment 2

# %%
B     = [0.433, -0.3050, 0.0734, 0.1257, 0.0607, -0.2380, -0.2553, -0.0331, 0.0364, 0.1664, -0.425]
A     = [1]
K      = 66
N     = 100000
sigma = 0.1
beta  = 1
name  = 'UCB_Power_Allocation'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %%
bandit = Bandits(A,B,K)
bandit.print_hinf_norm()
bandit.plot_real_system()
Model_UCBPA1 = UCB_Power_Allocation(bandit,sigma,N,prior,name,beta,"2")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 1.823838133951191 Which is in arm :  59

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBPA1)
Plot_Chosen_Time(Model_UCBPA1)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 5000
Regret_UCBPA1 = Model_Regret(Model_UCBPA1,Kn)
Regret_UCBPA1.Compute_Regret(showed=False,savefig = savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 91.35735142604312
# here
# The 2th model with the overall Regret: 81.17458937967577
# here
# The 3th model with the overall Regret: 87.4400181198972
# here
# The 4th model with the overall Regret: 83.81003760884585
# here
# The 5th model with the overall Regret: 85.70771389142988
# here
# The 6th model with the overall Regret: 83.51597399232871
# here
# The 7th model with the overall Regret: 87.11442712263025
# here
# The 8th model with the overall Regret: 75.67292987269595
# here
# The 9th model with the overall Regret: 80.98280750337386
# here
# The 10th model with the overall Regret: 93.78831618582284
# here
# The 11th model with the overall Regret: 166.41896779495397
# here
# The 12th model with the overall Regret: 121.08137259500874
# here
# The 13th model with the overall Regret: 100.24627461703139
# here
# The 14th model with the overall Regret: 92.48852554398647
# here
# The 15th model with the overall Regret: 94.56989042770685
# here
# The 16th model with the overall Regret: 108.79126647261666
# here
# The 17th model with the overall Regret: 115.88559593836455
# here
# The 18th model with the overall Regret: 80.55859290185636
# here
# The 19th model with the overall Regret: 98.87173861299594
# here
# The 20th model with the overall Regret: 87.58901001016459
# here
# The 21th model with the overall Regret: 90.31075134865905
# here
# The 22th model with the overall Regret: 99.71442568401842
# here
# The 23th model with the overall Regret: 79.62790604365156
# here
# The 24th model with the overall Regret: 99.5967539903148
# here
# The 25th model with the overall Regret: 96.50186195517426
# here
# The 26th model with the overall Regret: 98.55349015033715
# here

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBPA1)
Plot_Chosen_Time(Model_UCBPA1)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
Regret_UCBPA1.Plot_Regret(Skip=[],T = True)

# %% [markdown]
# ### Plot semilog MSE

# %%
plt.figure()
plt.semilogy(Regret_UCBPA1.MSE,label = 'MSE1')
plt.plot(Regret_UCBPA1.MSE1,label = 'MSE2')
plt.title("Mean Square Error of the experiment.")
plt.xlabel("Time t")
plt.ylabel("MSE")

plt.legend()
plt.show()

# %% [markdown]
# ### Save the Experiment 2 Result for Further Analysis

# %%
import pickle
with open('./Result/UCBPA_66arms_1e5rounds_EX2.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBPA1, handle, protocol=pickle.HIGHEST_PROTOCOL)
