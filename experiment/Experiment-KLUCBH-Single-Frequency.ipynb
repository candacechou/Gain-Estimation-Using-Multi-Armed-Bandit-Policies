# %% [markdown]
# # KLUCB-H with Single Frequency Strategy
#
# $\sigma$ = 0.1

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from bandit import Bandits
from KLUCB import KLUCB_Single_Freq
from Result_Visualization import System_Gain_Estimation,Plot_mean_square_error
from Regret import Model_Regret
from Model_Analysis import  Plot_Chosen_Time,System_Gain_Estimation_UCB

# %% [markdown]
# ## Experiment 1

# %%
B     = [0.1023, -0.1050, -0.0734, -0.2553, -0.0331, 0.2257, -0.0607, -0.2380, -0.0664, -0.1164, 0.1056]
A     = [1]
K     = 50
N     = 100000
sigma = 0.1
name  = 'KLUCB-H'

# %% [markdown]
# ### Create a bandit Object

# %%
bandit = Bandits(A,B,K)

bandit.print_hinf_norm()
bandit.plot_real_system()
c = 3
Model_UCBSF = KLUCB_Single_Freq(bandit,sigma,N,name,c,"1")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 0.7415136824155119 Which is in arm :  19

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF)
Plot_Chosen_Time(Model_UCBSF)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 3000
Regret_UCBSF = Model_Regret(Model_UCBSF,Kn)
Regret_UCBSF.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 77.66566641006894
# here
# The 2th model with the overall Regret: 90.6861757853639
# here
# The 3th model with the overall Regret: 83.19275296671044
# here
# The 4th model with the overall Regret: 77.05889275322569
# here
# The 5th model with the overall Regret: 74.27704338092066
# here
# The 6th model with the overall Regret: 85.6328630988329
# here
# The 7th model with the overall Regret: 77.40915177946721
# here
# The 8th model with the overall Regret: 77.8429663988008
# here
# The 9th model with the overall Regret: 102.38012901512431
# here
# The 10th model with the overall Regret: 79.6982763510201
# here
# The 11th model with the overall Regret: 92.4833729400738
# here
# The 12th model with the overall Regret: 80.55117487664667
# here
# The 13th model with the overall Regret: 84.97893075886414
# here
# The 14th model with the overall Regret: 68.49821363698966
# here
# The 15th model with the overall Regret: 90.4664421286319
# here
# The 16th model with the overall Regret: 75.46046149007633
# here
# The 17th model with the overall Regret: 81.58013620359236
# here
# The 18th model with the overall Regret: 73.67911287872562
# here
# The 19th model with the overall Regret: 70.13816402738844
# here
# The 20th model with the overall Regret: 78.87849235605943
# here
# The 21th model with the overall Regret: 78.53805067249696
# here
# The 22th model with the overall Regret: 73.25620788909195
# here
# The 23th model with the overall Regret: 71.71657469545234
# here
# The 24th model with the overall Regret: 79.01787421670983
# here
# The 25th model with the overall Regret: 87.22557503579452
# here
# The 26th model with the overall Regret: 70.64148976727394
# here
# The 27th model with the overall Regret: 81.17216123463524
# here
# The 28th model with the overall Regret: 103.39996875135768
# here
# The 29th model with the overall Regret: 70.65679336739774
# here
# The 30th model with the overall Regret: 71.5117912550866
# here
# The 31th model with the overall Regret: 78.57472195740094
# here
# The 32th model with the overall Regret: 74.20004783277003
# here
# The 33th model with the overall Regret: 77.13385399242895
# here
# The 34th model with the overall Regret: 77.24561027033933
# here
# The 35th model with the overall Regret: 68.60720332493506
# here
# The 36th model with the overall Regret: 68.09230136511155
# here
# The 37th model with the overall Regret: 72.31310699800272
# here
# The 38th model with the overall Regret: 75.09178458383167
# here
# The 39th model with the overall Regret: 72.58904330412571
# here
# The 40th model with the overall Regret: 75.40712467515698
# here
# The 41th model with the overall Regret: 79.65456640310546
# here
# The 42th model with the overall Regret: 91.46221134618449
# here
# The 43th model with the overall Regret: 73.1355535251969
# here
# The 44th model with the overall Regret: 86.58999185694553
# here
# The 45th model with the overall Regret: 74.60790287147783
# here
# The 46th model with the overall Regret: 79.42976848570893
# here
# The 47th model with the overall Regret: 71.9036600712949
# here
# The 48th model with the overall Regret: 84.69337453498532
# here
# The 49th model with the overall Regret: 71.71184187583482
# !here
# The 50th model with the overall Regret: 75.91997169693349

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF)
Plot_Chosen_Time(Model_UCBSF)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
plt.figure()
for i in range(Kn): 
    plt.plot(range(len(Regret_UCBSF.regret[:,i])),Regret_UCBSF.regret[:,i])
plt.xlabel("Time")
plt.ylabel("Regret")
plt.title("The regret of each model.")
plt.show()

# %% [markdown]
# ### Plot the Expected regret

# %%
Regret_UCBSF.Plot_Regret()

# %% [markdown]
# ### Plot the Mean Square Error

# %%
Regret_UCBSF.Plot_MSE()

# %% [markdown]
# ### Plot Regret with Regret lower bound on in semi-log

# %%
Regret_UCBSF.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
Regret_UCBSF.Plot_MSE()

# %% [markdown]
# ### Save the Experiment 1 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBHSF_50arms_1e5rounds_EX1.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBSF, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Experiment 2

# %%
B     = [0.433, -0.3050, 0.0734, 0.1257, 0.0607, -0.2380, -0.2553, -0.0331, 0.0364, 0.1664, -0.425]
A     = [1]
K      = 66
N     = 100000
sigma = 0.1
c = 3
name  = 'KLUCB-H'

# %%
bandit = Bandits(A,B,K)
bandit.print_hinf_norm()
bandit.plot_real_system()
Model_UCBSF1 = KLUCB_Single_Freq(bandit,sigma,N,name,c,"2")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 1.823838133951191 Which is in arm :  59

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF1)
Plot_Chosen_Time(Model_UCBSF1)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 3000
Regret_UCBSF1 = Model_Regret(Model_UCBSF1,Kn)
Regret_UCBSF1.Compute_Regret(savefig=savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# here
# The 1th model with the overall Regret: 124.26273289333096
# here
# The 2th model with the overall Regret: 110.78403579603055
# here
# The 3th model with the overall Regret: 101.96679548967248
# here
# The 4th model with the overall Regret: 113.02082887813371
# here
# The 5th model with the overall Regret: 98.46600385061953
# here
# The 6th model with the overall Regret: 125.68516129510043
# here
# The 7th model with the overall Regret: 130.62794361500627
# here
# The 8th model with the overall Regret: 120.85424466763956
# here
# The 9th model with the overall Regret: 117.45482068524389
# here
# The 10th model with the overall Regret: 128.4163241400905
# here
# The 11th model with the overall Regret: 124.11081197439717
# here
# The 12th model with the overall Regret: 126.96848273195793
# here
# The 13th model with the overall Regret: 123.43975758746917
# here
# The 14th model with the overall Regret: 98.5754802644552
# here
# The 15th model with the overall Regret: 125.72135371260806
# here
# The 16th model with the overall Regret: 107.19498662480652
# here
# The 17th model with the overall Regret: 116.53904320713337
# here
# The 18th model with the overall Regret: 136.82215080948265
# here
# The 19th model with the overall Regret: 120.50025158216172
# here
# The 20th model with the overall Regret: 97.57337549123481
# here
# The 21th model with the overall Regret: 121.82908831233215
# here
# The 22th model with the overall Regret: 120.27540212323066
# here
# The 23th model with the overall Regret: 117.17052463782933
# here
# The 24th model with the overall Regret: 126.3311228027331
# here
# The 25th model with the overall Regret: 130.2232982857601
# here
# The 26th model with the overall Regret: 142.23573342886297
# here
# The 27th model with the overall Regret: 115.04826150526362
# here
# The 28th model with the overall Regret: 138.73829093922527
# here
# The 29th model with the overall Regret: 129.51186968421567
# here
# The 30th model with the overall Regret: 124.92526601852128
# here
# The 31th model with the overall Regret: 114.91635969296534
# here
# The 32th model with the overall Regret: 116.51470521463989
# here
# The 33th model with the overall Regret: 141.04857067171417
# here
# The 34th model with the overall Regret: 130.5899345811634
# here
# The 35th model with the overall Regret: 133.77950663526013
# here
# The 36th model with the overall Regret: 119.85036043454072
# here
# The 37th model with the overall Regret: 139.94229457340379
# here
# The 38th model with the overall Regret: 115.76159882809901
# here
# The 39th model with the overall Regret: 118.9615134486215
# here
# The 40th model with the overall Regret: 112.0862478958353
# here
# The 41th model with the overall Regret: 128.35032001232187
# here
# The 42th model with the overall Regret: 145.28864267971178
# here
# The 43th model with the overall Regret: 114.25670430117283
# here
# The 44th model with the overall Regret: 131.94160766220327
# here
# The 45th model with the overall Regret: 132.03578998429603
# here
# The 46th model with the overall Regret: 114.46423552322787
# here
# The 47th model with the overall Regret: 120.30551524396428
# here
# The 48th model with the overall Regret: 112.744186865233
# here
# The 49th model with the overall Regret: 123.64003457102794
# !here
# The 50th model with the overall Regret: 118.86852055138948

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_UCBSF1)
Plot_Chosen_Time(Model_UCBSF1)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
Regret_UCBSF1.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:100: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
Regret_UCBSF1.Plot_MSE()

# %% [markdown]
# ### Save the Experiment 2 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBHSF_66arms_1e5rounds_EX2.pkl', 'wb') as handle:
    pickle.dump(Regret_UCBSF1, handle, protocol=pickle.HIGHEST_PROTOCOL)
