# %% [markdown]
# # KLUCB with Power Allocation Strategy
#
# $\sigma$ = 0.1

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from bandit import Bandits
from KLUCB import KLUCB_Power_Allocation
from Result_Visualization import System_Gain_Estimation,Plot_mean_square_error
from Regret import Model_Regret
from Model_Analysis import Plot_Chosen_Time,System_Gain_Estimation_UCB

# %% [markdown]
# ## Experiment 1

# %%
B     = [0.1023, -0.1050, -0.0734, -0.2553, -0.0331, 0.2257, -0.0607, -0.2380, -0.0664, -0.1164, 0.1056]
A     = [1]
K     = 50
N     = 100000
sigma = 0.1
beta  = 1
c = 3
name  = 'KLUCB'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %% [markdown]
# ### Create a bandit Object

# %%
bandit = Bandits(A,B,K)

bandit.print_hinf_norm()
bandit.plot_real_system()

Model_KLUCBPA = KLUCB_Power_Allocation(bandit,sigma,N,name,prior,c,"1")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 0.7415136824155119 Which is in arm :  19

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_KLUCBPA)
Plot_Chosen_Time(Model_KLUCBPA)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 5000
Regret_KLUCBPA = Model_Regret(Model_KLUCBPA,Kn)
Regret_KLUCBPA.Compute_Regret(showed=False,savefig = savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/KLUCB.py:279: RuntimeWarning: divide by zero encountered in log
#   if self.c * np.log(np.log(t+1))+ np.log(t+1) < 0:
# The 1th model with the overall Regret: 45.913229742460345
# The 2th model with the overall Regret: 49.276248170442884
# The 3th model with the overall Regret: 74.65742207480491
# The 4th model with the overall Regret: 50.26451827545367
# The 5th model with the overall Regret: 44.59821391958415
# The 6th model with the overall Regret: 47.18372500772384
# The 7th model with the overall Regret: 47.5349038666976
# The 8th model with the overall Regret: 47.242353463957166
# The 9th model with the overall Regret: 40.42378125016746
# The 10th model with the overall Regret: 39.54120729033133
# The 11th model with the overall Regret: 46.271196513265686
# The 12th model with the overall Regret: 51.33302886788137
# The 13th model with the overall Regret: 41.18597675220772
# The 14th model with the overall Regret: 40.46330457817221
# The 15th model with the overall Regret: 42.8396344089667
# The 16th model with the overall Regret: 47.70646955721593
# The 17th model with the overall Regret: 57.98818908125674
# The 18th model with the overall Regret: 45.27924980455542
# The 19th model with the overall Regret: 48.96380901745704
# The 20th model with the overall Regret: 48.99025195822412
# The 21th model with the overall Regret: 46.00153088850242
# The 22th model with the overall Regret: 53.55073865095114
# The 23th model with the overall Regret: 44.26422531104871
# The 24th model with the overall Regret: 43.19147045714525
# The 25th model with the overall Regret: 41.07073001677126
# The 26th model with the overall Regret: 44.95349381887432
# The 27th model with the overall Regret: 43.36647445686341
# The 28th model with the overall Regret: 47.79050745125224
# The 29th model with the overall Regret: 38.37957472175074
# The 30th model with the overall Regret: 42.87431080128421
# The 31th model with the overall Regret: 52.03351156527828
# The 32th model with the overall Regret: 48.59543620775518
# The 33th model with the overall Regret: 39.62443905155544
# The 34th model with the overall Regret: 44.58927736133557
# The 35th model with the overall Regret: 38.31366619750034
# The 36th model with the overall Regret: 49.018716378841496
# The 37th model with the overall Regret: 44.72260463106898
# The 38th model with the overall Regret: 45.07676530237151
# The 39th model with the overall Regret: 52.593382748978776
# The 40th model with the overall Regret: 31.68909701975447
# The 41th model with the overall Regret: 57.466321499063504
# The 42th model with the overall Regret: 38.69889966553812
# The 43th model with the overall Regret: 47.99224037930922
# The 44th model with the overall Regret: 51.67921806397295
# The 45th model with the overall Regret: 43.29975292095638
# The 46th model with the overall Regret: 47.719322700672535
# The 47th model with the overall Regret: 45.32568550329427
# The 48th model with the overall Regret: 50.05993649679444
# The 49th model with the overall Regret: 47.25151555156018
# The 50th model with the overall Regret: 40.587575758788425

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
plt.figure()
for i in range(Kn): 
    plt.plot(range(len(Regret_KLUCBPA.regret[:,i])),Regret_KLUCBPA.regret[:,i])
plt.xlabel("Time")
plt.ylabel("Regret")
plt.title("The regret of each model.")
plt.show()

# %% [markdown]
# ### Plot the Expected regret

# %%
Regret_KLUCBPA.Plot_Regret()

# %% [markdown]
# ### Plot the Mean Square Error

# %%
Regret_KLUCBPA.Plot_MSE()

# %% [markdown]
# ### Plot Regret with Regret lower bound on in semi-log

# %%
Regret_KLUCBPA.Plot_Regret(T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:98: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
plt.figure()
plt.semilogy(Regret_KLUCBPA.MSE,label = 'MSE1')
plt.plot(Regret_KLUCBPA.MSE1,label = 'MSE2')
plt.title("Mean Square Error of the experiment.")
plt.xlabel("Time t")
plt.ylabel("MSE")

plt.legend()
plt.show()

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_KLUCBPA)
Plot_Chosen_Time(Model_KLUCBPA)

# %% [markdown]
# ### Save the Experiment 1 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBPA_50arms_1e5rounds_EX1.pkl', 'wb') as handle:
    pickle.dump(Regret_KLUCBPA, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Experiment 2

# %%
B     = [0.433, -0.3050, 0.0734, 0.1257, 0.0607, -0.2380, -0.2553, -0.0331, 0.0364, 0.1664, -0.425]
A     = [1]
K      = 66
N     = 100000
sigma = 0.1
beta  = 1
c     = 3
name  = 'KLUCB'

# %% [markdown]
# ### Giving Uniform distribution of each arm

# %%
prior = [np.random.random() for i in range(K)]
prior /= np.sum(prior)

# %%
bandit = Bandits(A,B,K)
bandit.print_hinf_norm()
bandit.plot_real_system()
Model_KLUCBPA1 = KLUCB_Power_Allocation(bandit,sigma,N,name,prior,c,"2")
# Out:
# Generating the arms....
# Analysing the norms...
# The hinf norm on this system is : 1.823838133951191 Which is in arm :  59

# %% [markdown]
# ### Before starting the experiment, the prior of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_KLUCBPA1)
Plot_Chosen_Time(Model_KLUCBPA1)

# %% [markdown]
# ### Run the experiments
#
# We run the experiments 50 times to calculate the emperical rewards and the regrets.

# %%
Kn = 50
savefig = True
frame = 5000
Regret_KLUCBPA1 = Model_Regret(Model_KLUCBPA1,Kn)
Regret_KLUCBPA1.Compute_Regret(showed=False,savefig = savefig,frame=frame)
# Out:
# Start to train the model!
# =============================
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/KLUCB.py:279: RuntimeWarning: divide by zero encountered in log
#   if self.c * np.log(np.log(t+1))+ np.log(t+1) < 0:
# The 1th model with the overall Regret: 1606.7140219188148
# The 2th model with the overall Regret: 40.4416457442946
# The 3th model with the overall Regret: 1602.8955765503474
# The 4th model with the overall Regret: 69.71302420640826
# The 5th model with the overall Regret: 68.29709588994827
# The 6th model with the overall Regret: 44.986047676618675
# The 7th model with the overall Regret: 41.624699589670115
# The 8th model with the overall Regret: 76.73939529338863
# The 9th model with the overall Regret: 50.363396998134476
# The 10th model with the overall Regret: 1605.5169191762457
# The 11th model with the overall Regret: 43.54653354418691
# The 12th model with the overall Regret: 65.69360282949108
# The 13th model with the overall Regret: 63.81352749234602
# The 14th model with the overall Regret: 56.35051092647174
# The 15th model with the overall Regret: 62.899231019665606
# The 16th model with the overall Regret: 53.59967989221213
# The 17th model with the overall Regret: 44.8086117336343
# The 18th model with the overall Regret: 56.398572974330186
# The 19th model with the overall Regret: 59.28731241453877
# The 20th model with the overall Regret: 54.065264788474636
# The 21th model with the overall Regret: 1608.7931495586174
# The 22th model with the overall Regret: 58.82238263632606
# The 23th model with the overall Regret: 55.88080783145604
# The 24th model with the overall Regret: 44.47859199855175
# The 25th model with the overall Regret: 49.1077032311554
# The 26th model with the overall Regret: 57.24861040816349
# The 27th model with the overall Regret: 61.0674652684011
# The 28th model with the overall Regret: 1035.522098388953
# The 29th model with the overall Regret: 49.72825577388682
# The 30th model with the overall Regret: 1595.1443036054764
# The 31th model with the overall Regret: 42.075712926531835
# The 32th model with the overall Regret: 56.81223078020738
# The 33th model with the overall Regret: 125.90719892554294
# The 34th model with the overall Regret: 48.523854969874286
# The 35th model with the overall Regret: 44.392233663566486
# The 36th model with the overall Regret: 70.97619755002953
# The 37th model with the overall Regret: 1618.19456083899
# The 38th model with the overall Regret: 63.61573704593118
# The 39th model with the overall Regret: 45.783493516349054
# The 40th model with the overall Regret: 68.17698954074524
# The 41th model with the overall Regret: 52.87306344030971
# The 42th model with the overall Regret: 56.83485638981478
# The 43th model with the overall Regret: 51.52151055748656
# The 44th model with the overall Regret: 53.983262988927144
# The 45th model with the overall Regret: 50.989869814255556
# The 46th model with the overall Regret: 96.99017665833509
# The 47th model with the overall Regret: 55.06083914523653
# The 48th model with the overall Regret: 45.2512208617643
# The 49th model with the overall Regret: 41.22586828564894
# The 50th model with the overall Regret: 281.36554393843045

# %% [markdown]
# ### After experiment, the estimation of the gain looks like ...

# %%
System_Gain_Estimation_UCB(Model_KLUCBPA1)
Plot_Chosen_Time(Model_KLUCBPA1)

# %% [markdown]
# ### Plot the regret over 50 experiments.

# %%
Regret_KLUCBPA1.Plot_Regret(Skip=[],T = True)
# Out:
# /Users/candacechou/homework/Gain-Estimation-Using-Multi-Armed-Bandit-Policies/experiment/Regret.py:98: RuntimeWarning: divide by zero encountered in log
#   lower_bound = np.sum(delta) * np.log(range(self.model.N+1))

# %% [markdown]
# ### Plot semilog MSE

# %%
plt.figure()
plt.semilogy(Regret_KLUCBPA1.MSE,label = 'MSE1')
plt.plot(Regret_KLUCBPA1.MSE1,label = 'MSE2')
plt.title("Mean Square Error of the experiment.")
plt.xlabel("Time t")
plt.ylabel("MSE")

plt.legend()
plt.show()

# %% [markdown]
# ### Save the Experiment 2 Result for Further Analysis

# %%
import pickle
with open('./Result/KLUCBPA_66arms_1e5rounds_EX2.pkl', 'wb') as handle:
    pickle.dump(Regret_KLUCBPA1, handle, protocol=pickle.HIGHEST_PROTOCOL)
